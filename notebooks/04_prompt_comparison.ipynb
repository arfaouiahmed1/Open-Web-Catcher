# %% [markdown]
# # 04 — Prompt A/B Comparison
#
# Compare performance of different prompt versions per agent.

# %%
import pandas as pd

# Load results tagged by prompt version
# Assumes result_json contains a 'prompt_version' field
df = pd.read_csv('../data/processed/metrics.csv')

# TODO: parse prompt_version from result_json column
# df['prompt_version'] = df['result_json'].apply(lambda x: json.loads(x).get('prompt_version', 'v1'))

print('Notebook stub — populate with A/B test data')
df.head()
