# %% [markdown]
# # 01 — Data Exploration
#
# Dataset overview: site distribution, page types, collection period.

# %%
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('../data/processed/metrics.csv')
print(df.shape)
df.head()

# %%
df['page_type'].value_counts().plot(kind='bar', title='Page Type Distribution')
plt.tight_layout()
plt.show()
