# %% [markdown]
# # 05 — Model Comparison
#
# Gemini Flash vs Flash-Lite vs Pro: success rate, token cost, latency.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load results tagged by model name
df = pd.read_csv('../data/processed/metrics.csv')

# TODO: parse model from result_json column
# df['model'] = df['result_json'].apply(lambda x: json.loads(x).get('model', 'gemini-1.5-flash'))

print('Notebook stub — populate with multi-model run data')
df.head()
